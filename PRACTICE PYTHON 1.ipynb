# %%
# python types and sequences
# the python language has a built-in funstion called type which will give you what type a given refence is! 
type('hi Tamim')
# Out:
# str

# %%
type(None)
# Out:
# NoneType

# %%
type(1)
# Out:
# int

# %%
type(1.0)
# Out:
# float

# %%
def add_numbers(a,b):
  return a+b

p = add_numbers(2,3)
print(p, type(add_numbers))
# Out:
# 5 <class 'function'>

# %% [markdown]
# Find out the smallest number from a list. (e.g. [99,11,74] here, 11 is smallest]

# %%
list = [78, 99, 100, 135, 75]

print("the smallest number is", list(min))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-71280f1b1b06> in <module>()
#       1 list = [78, 99, 100, 135, 75]
#       2
# ----> 3 print("the smallest number is", list(min))
#
# TypeError: 'list' object is not callable

# %% [markdown]
# Problem 1: Create a program that asks the user to enter their name and their age. Print out a message addressed to them that tells them the year that they will turn 100 years old.

# %%
Name = input()

Age = float(input())
  
 
equation = str(100 - Age)

print('Hi', Name)
print("You are bow", Age)
print("After", equation, "years you will turn into 100 years")

# %% [markdown]
# # New Section

# %% [markdown]
# Problem 2: Ask the user for a number. Depending on whether the number is even or odd, print out an appropriate message to the user.

# %%
x = int(input('Enter a Number:'))

if x/2 == 0:
  print("The number is even", x)

else:
  print( x, 'So, the number is odd',)
# Out:
# Enter a Number:42
# 42 So, the number is odd

# %% [markdown]
# Print the numbers from 121 to 130

# %%
def  series(n):
    n = 0
    for n in range(121,131):
      print(n)

series(n)
# Out:
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130

# %% [markdown]
# Find the sum of even numbers from 1 to 10

# %%
n = 0

for n in range (0,10,2):
  n = n+2

print(n)
# Out:
# 10

# %% [markdown]
# Find the sum of even numbers from 1 to 10

# %%
class sumumation:
  
  def __init__ (self, sum):
    self.sum = sum
    sum = sum + 2
    return sum

  def series(sum):
   for sum in range(1,10):
     print(n)

summation(n)
print(series.summation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-307b9637fdd3> in <module>()
#      10      print(n)
#      11
# ---> 12 summation(n)
#      13 print(series.summation)
#
# NameError: name 'summation' is not defined
